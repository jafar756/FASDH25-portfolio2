# %% [markdown]
# # Using stanza for Named Entity Recognition (continued)

# %% [markdown]
# ## Installation
#
# Run the code cell below to install stanza:

# %%
# !pip install stanza
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.11/dist-packages (1.10.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/dist-packages (from stanza) (2.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)

# %% [markdown]
# ## Import library and download language model
#
# After installing it, we import stanza into our notebook.

# %%
import stanza
import os
import re

# %% [markdown]
# ## Creating the pipeline
#
# Download the English language model and build the pipeline (we specify that it should only tokenize the text, separate multiword tokens and perform Named Entity Recognition):

# %%
stanza.download("en")
nlp = stanza.Pipeline(lang="en", processors='tokenize,mwt,ner')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: en (English) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.10.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: en (English):
# =========================================
# | Processor | Package                   |
# -----------------------------------------
# | tokenize  | combined                  |
# | mwt       | combined                  |
# | ner       | ontonotes-ww-multi_charlm |
# =========================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %% [markdown]
# #Use the corpus in the portfolio repo
# Instead of using the corpus texts in the “session_10.1” folder, your script should use
# the (much larger) corpus folder in your fork of the portfolio repository.

# %%
# !git clone https://github.com/jafar756/FASDH25-portfolio2.git
# Out:
# Cloning into 'FASDH25-portfolio2'...
# remote: Enumerating objects: 4386, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 4386 (delta 10), reused 7 (delta 7), pack-reused 4370 (from 2)
# Receiving objects: 100% (4386/4386), 17.82 MiB | 22.59 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %% [markdown]
# #Extract only the place names from the articles written in January 2024
# Use a condition to make sure that only place names from articles written in January
# 2024 are extracted.

# %%
# Now I will Define the path where the text files (articles) are stored
corpus_path = "/content/FASDH25-portfolio2/articles"
# start an empty list to store paths of matching
jan_files = []
# Now going through the directory and its subdirectories
for root, _, files in os.walk(corpus_path):
  # Loop through all files in the current directory
    for file in files:
      # Check if the file is from January 2024 and ends with '.txt'
        if '2024-01' in file and file.endswith('.txt'):
            jan_files.append(os.path.join(root, file))

# print the total number of matching files found
print(f"Found {len(jan_files)} January 2024 files.")
# Out:
# Found 326 January 2024 files.

# %% [markdown]
# # Place names : Count the number times each named entity that refers to a place is mentioned
# in these texts

# %%
# Step 2: Create a dictionary to store place counts
place_counts = {}

# Step 3: Set your folder path (use raw string r"" to avoid issues with backslashes)
corpus_path = "/content/FASDH25-portfolio2/articles"


# Step 5: Process each file
for filepath in jan_files:
    with open(filepath, 'r', encoding='utf-8') as file:
        text = file.read()
        doc = nlp(text)
        for ent in doc.ents:
            if ent.type in ['GPE', 'LOC']:
                place_name = ent.text.strip()
                if place_name in place_counts:
                    place_counts[place_name] += 1
                else:
                    place_counts[place_name] = 1

# Step 6: Print all place names and counts
for place, count in place_counts.items():
    print(f"{place}: {count}")
# Out:
# Morocco: 13
# Israel: 1593
# Gaza: 1605
# Rabat: 3
# United States: 40
# the United Arab Emirates: 13
# UAE: 7
# Bahrain: 11
# Sudan: 3
# US: 706
# Western Sahara: 3
# Washington: 60
# Tel Aviv: 49
# Algeria: 7
# Marrakesh: 1
# the Western Sahara: 1
# Morocco’s: 1
# Maghreb: 1
# Ukraine: 47
# Saudi Arabia: 39
# California: 3
# West Bank: 120
# Dena: 1
# Israel’s: 31
# Oakland: 1
# the United States: 97
# South Africa: 200
# Jordan: 42
# Jerusalem: 26
# East Jerusalem: 23
# Egypt: 43
# Qatar: 64
# Kuala Lumpur: 4
# Malaysia: 8
# Palestine: 124
# Indonesia’s: 1
# Jakarta: 2
# Johannesburg: 4
# London: 17
# Paris: 8
# Vienna: 1
# Berlin: 5
# Amman: 6
# Washington DC: 3
# UK: 95
# Manchester: 1
# Yemen: 182
# Washington, DC: 4
# India: 50
# Hyderabad: 1
# Colombo’s Kollupitiya: 1
# Namibia: 10
# Germany: 31
# Palestinian Territories: 1
# Sweden: 2
# Iran: 206
# Kerman: 6
# Lebanon: 175
# Bethlehem: 4
# Nairoukh: 1
# China: 28
# Italy: 10
# Spain: 7
# Turkey: 25
# Shawawra: 1
# The Hague: 33
# South Africa’s: 8
# the Gaza Strip: 123
# Khan Younis: 23
# Syria: 83
# Mazzeh: 2
# Damascus: 17
# U.S.: 11
# Houthis’: 3
# the Red Sea: 194
# the Bab-el-Mandeb Strait: 1
# the Gulf of Aden: 23
# Sanaa: 15
# the United Kingdom: 28
# Hodeidah: 5
# Taiz: 2
# Dhamar: 1
# al-Bayda: 1
# Saada: 3
# the Arabian Sea: 6
# the Bab al-Mandeb Strait: 5
# Asia: 18
# Europe: 30
# Kuwait: 2
# Middle East: 25
# Ankara: 7
# Red Sea: 50
# United Kingdom: 12
# West: 24
# Tehran: 25
# the Middle East: 77
# South Carolina: 4
# New York City: 1
# Gaza’s: 18
# Gaza City: 31
# Rafah: 40
# Gaza Strip: 31
# Strip: 14
# Istanbul: 2
# Greece: 8
# Crete: 2
# Washington’s: 2
# Sweden's: 1
# Iraq: 62
# Gulf: 10
# al-Dabshah: 1
# Khirbet Selm: 1
# Bint Jbeil: 1
# Beirut: 84
# Ibil El Saqi: 1
# al-Tawil’s: 1
# al-Khader: 1
# the Bekaa Valley: 1
# the Litani River: 1
# Netherlands: 14
# Malta: 2
# the Gulf of Oman: 2
# Davos: 7
# Switzerland: 9
# Deir el-Balah: 14
# Maghazi: 5
# Nuseirat: 11
# Manchester City: 1
# Barcelona: 1
# Bab el-Mandeb strait: 1
# Djibouti: 4
# Southern Red Sea: 1
# Africa’s Cape of Good Hope: 1
# al-Shifa: 2
# The United States: 21
# Gretna: 2
# Louisiana: 3
# New Orleans: 5
# the West Bank: 40
# @MirandaCleland: 1
# France: 13
# the Strip: 1
# @majedalansari: 1
# Kan: 1
# al-Mawasi district: 2
# Mediterranean: 11
# Africa: 29
# Jenin: 19
# Thameen Darby: 1
# the Nakba Layer: 1
# Russia: 43
# Canada: 42
# Mercator: 1
# Alaska: 1
# Mexico: 5
# South America: 2
# the Asia-Pacific: 1
# Golan Heights: 1
# The Golan Heights: 1
# Crimea: 4
# the South China Sea: 1
# South China Sea: 1
# Philippines: 4
# Vietnam: 1
# Pakistan: 24
# Kashmir: 4
# New Delhi: 6
# Islamabad: 3
# Darby’s Nakba: 1
# the State of Israel: 7
# Hebron: 10
# Lama Khater: 1
# Kiryat Arba: 2
# Bureij: 2
# al-Mahatta: 1
# Belgium: 15
# al-Mazra’a: 1
# the Mediterranean Sea: 2
# Ajaq: 1
# Silwad: 1
# Cairo: 6
# Yemen’s: 6
# Australia: 12
# Denmark: 3
# New Zealand: 2
# South Korea: 1
# Norway: 11
# Hamas’s: 6
# Yaroun: 3
# Lebanon’s Nabatieh: 1
# Yir’on: 1
# Avivim: 1
# Israel’s Goren: 1
# Shatila: 3
# Dahiyeh: 6
# DC: 14
# Doha: 19
# Lisbon: 1
# Portugal: 3
# Walla: 2
# Somalia: 1
# Yemen’s Red Sea: 1
# Gulf of Aden: 4
# Yemen’s coast: 2
# Lebanon’s: 3
# Seychelles: 1
# Bab al-Mandeb strait: 3
# North Africa: 5
# Marib: 3
# the Gaza strip: 1
# Gaza Strip’s: 3
# Khreis’s: 1
# Northern Gaza: 1
# Hong Kong: 2
# the State of Palestine: 1
# Bolivia: 4
# Bangladesh: 2
# Comoros: 2
# The United Kingdom: 3
# Myanmar: 6
# north📍#Gaza: 1
# Erbil: 13
# Pakistan’s Balochistan province: 2
# Iran’s Sistan-Baluchestan province: 2
# Iran’s: 3
# Afghanistan: 7
# Rask: 1
# Sistan-Baluchestan: 1
# the Strait of Hormuz: 3
# the Persian Gulf: 1
# Balochistan: 1
# the Red Sea.: 1
# La France: 1
# WestBank: 2
# Entebbe: 1
# Uganda: 11
# Montreal: 1
# Milton, Ontario: 1
# Jabalia: 11
# Ottawa: 3
# Toronto: 1
# Calgary: 1
# New York: 4
# Belarus: 1
# Munich: 2
# Haifa: 8
# Sidon: 3
# Salameh’s: 1
# Beirut’s: 3
# Gaza’s Deir el-Balah: 3
# al-Mughraqa: 1
# al-Maghazi: 1
# Maghazi Roads: 1
# Deir al-Balah: 1
# the Islamic Republic: 3
# Nur Shams: 1
# Tulkarem: 2
# Naqoura: 2
# America: 4
# France’s: 1
# El Arish: 3
# Al Jazeera’s: 1
# al-Mawasi: 3
# Beirut’s Shatila: 1
# Al-Fukhari: 1
# Zeitoun: 4
# al-Fukhari: 2
# Britain: 14
# the Republic of Yemen: 1
# Hajjah: 2
# Ramallah: 24
# Abwein: 1
# Nablus: 5
# Qalqilya: 2
# Jericho: 1
# Ein al-Hilweh: 1
# Basel: 3
# Ofer: 1
# the Jordan Valley: 5
# Area C: 6
# Kadri’s: 1
# al-Jiftlik: 1
# Farsiya: 1
# Makhoul: 1
# Tubas: 1
# Areas A: 1
# Japan: 9
# Silicon Valley: 3
# Netanyahu’s: 7
# West Jerusalem: 1
# Brussels: 5
# the League of Arab States: 1
# West Beirut: 9
# Beirut’s Hamra: 1
# Hamra’s: 1
# Hamra: 2
# West Beirutis: 1
# Dabbouch: 1
# East Beirut: 1
# Austria: 3
# Finland: 3
# Iceland: 1
# Romania: 4
# Melbourne, Australia: 1
# Melbourne: 5
# Sandridge Beach: 1
# the ZIM Ganges: 5
# Australia’s: 1
# Sydney: 1
# Brisbane: 1
# Rawaa’s: 1
# the Middle East Eye: 1
# the Near East: 3
# Kyiv: 5
# Houthi: 3
# Aqaba: 1
# the Marshall Islands: 1
# Aden: 3
# Bab al-Mandeb Strait: 4
# Sabra: 1
# Farhana: 1
# Abudaqa: 2
# Israel-Palestine: 2
# Shujayea: 3
# Khan Yunis: 1
# Mawasi: 1
# Wadi Gaza: 3
# Bosnia: 3
# Sri Lanka: 2
# the Republic of South Africa: 1
# Columbia: 3
# Chile: 4
# Chile’s: 1
# Santiago: 1
# Taiz province: 1
# Al-Bayda: 1
# Ashdod: 2
# Hebrew: 1
# X.
# Spain: 1
# Madrid: 1
# Oman: 1
# The United Arab Emirates: 1
# Charleston: 1
# Geneva: 2
# Al-Aqsa: 1
# Zawayda: 1
# Beit Hanoon: 1
# Serbia: 3
# Bosnia-Herzegovina: 1
# Srebrenica: 1
# Bani Suheila: 2
# Caesarea: 2
# Kefar Sava: 1
# Rehovot: 1
# Beersheba: 1
# Kiryat Shmona: 1
# the Blue Line: 1
# Baghdad: 8
# Middle Eastern: 3
# Welch’s: 1
# the Global South: 2
# The Gaza Strip: 1
# @NaksBilal: 1
# the Gaza Strip: 1
# Beit Lahiya: 2
# El Amal City Hospital: 1
# Iraq’s: 2
# Maroun El Ras: 1
# Rmeish: 1
# Miraj: 1
# Tal al-Hawa: 1
# @zarahsultana: 1
# Gisha: 1
# Bani Naim: 1
# Raanana: 1
# Sderot: 2
# Nir Am: 1
# Mefalsim: 1
# Hanita: 1
# Mattat: 1
# Margaliot: 1
# Adamit: 1
# Zar’it: 1
# Malkia: 1
# Herzegovina: 1
# Montenegro: 1
# Yugoslavia: 2
# Moscow: 4
# Pretoria: 8
# Mozambique: 1
# United States’: 2
# The Red Sea: 5
# Bulgaria: 1
# Shadi’s: 1
# Ebel el-Saqi: 1
# Panjgur: 1
# the Sistan-Baluchestan province: 1
# the Islamic Republic of Iran: 1
# Ocean Jazz: 1
# the Cape of Good Hope: 12
# al-Walaja: 5
# Gilo: 1
# Har Gilo: 1
# Singapore: 2
# Ras Issa: 1
# Hodeidah province: 1
# Dearborn: 12
# Michigan: 12
# Mackinac Island: 1
# Great Lakes: 1
# Lake Michigan: 1
# Texas: 3
# Beit Nabala: 1
# Idlib: 3
# Riyadh: 5
# Alborz: 4
# Southern Africa: 2
# Bab al-Mandeb: 2
# Venezuela: 1
# Hormuz: 1
# the Arabian Gulf: 1
# Dublin: 3
# Al Rayyan: 1
# Qatar’s: 1
# Cape Town: 2
# South Africansfrom: 1
# Africa4Palestine: 1
# Western Cape province: 1
# Chicago: 2
# Cyprus: 9
# Akrotiri: 12
# Limassol: 1
# Pashias: 1
# Anadolu: 1
# Nevatim: 1
# the Republic of Cyprus: 2
# Dhekelia: 1
# USA: 2
# al-Saftawi: 1
# Detroit: 1
# Southeast Michigan: 1
# Arab America: 1
# Jarrah: 1
# Wayne County: 1
# Minnesota: 1
# Scotland: 2
# Ireland: 3
# #October7: 2
# Entebbe, Uganda: 1
# Sierra Leone: 1
# DRC: 1
# @adoniaayebare: 1
# Hague: 6
# Dahiyeb: 1
# Aroura: 2
# al-Arouri: 2
# Salem: 1
# Copenhagen: 1
# Tunisia: 2
# Syria’s Aleppo: 1
# Mariupol: 1
# the Indian Ocean: 2
# Israel's: 1
# the Golan Heights: 1
# Kanaker: 1
# Sarit: 1
# Aleppo: 2
# Jordan’s: 1
# al-Tanf: 1
# the Hashemite Kingdom of Jordan: 1
# the Jordan River: 1
# @Palestine_UN: 1
# India’s Basmati: 1
# North America: 2
# Central Gaza Strip: 2
# Earth: 1
# al-Amal: 4
# al-Nasser: 1
# al-Katiba: 1
# Tel Aviv’s: 2
# Rohtak: 6
# Haryana: 3
# Uttar Pradesh: 1
# Lucknow: 1
# UP: 1
# Bihar: 4
# West Bengal: 1
# @Benarasiyaa: 1
# Haryana’s Panipat: 1
# Thailand: 2
# Haryana’s Jind: 1
# Al Maniya: 1
# Egypt’s: 1
# the Bab al-: 1
# Mandeb Strait: 1
# al-Mazraa Asharqiya: 1
# Harvey: 1
# Tawfiq: 1
# al-Mazra’a Asharqiya: 1
# Hamoud: 1
# Taalbaya: 1
# Rashidiya: 1
# Karem Abu Salem: 1
# Kerem Shalom: 1
# Estonia: 1
# Indonesia: 2
# Kampala: 5
# Uganda’s: 1
# Peru: 1
# Colombia: 1
# South Sudan: 1
# Swaziland: 1
# #RedSea: 1
# China’s: 2
# Bern: 1
# Zurich: 1
# Arura: 2
# Beruit: 1
# Hezbollah’s: 1
# Deir Qaddis: 1
# MoTaz: 1
# @azaizamotaz9: 1
# Israel’s Haifa: 1
# Dubai: 1
# Yemen’s southern coast: 1
# Egypt’s Sinai Peninsula: 1
# Philadelphi: 1
# Dahiya: 1
# Jama’a Islamiya: 2
# The Islamic Republic: 2
# Cameroon: 1
# al-Ahli: 1
# Des Moines: 7
# Iowa: 12
# Cedar Rapids: 5
# Iowa City: 5
# South Asia: 1
# Florida: 1
# New York’s Ellis Island: 1
# Ohio: 1
# Czech Republic: 1
# Hungary: 1
# Slovenia: 1
# @carogennez: 1
# Belgium’s: 1
# Flanders: 1
# Wallonia: 1
# Gaza city: 1
# West Bank’s: 2
# Supernova: 1
# Syria’s Damascus: 1
# Syria’s: 1
# Borj el Barajneh: 1
# Tel Israel’s: 1
# Libya: 3
# Rwanda: 1
# East Timor: 1
# Kabul: 1
# az-Zahra: 1
# Hamad: 1
# the State of Qatar: 1
# QFFD: 1
# Aizawl: 6
# Manipur: 8
# Kangpokpi: 1
# Mizoram: 7
# Mizoram’s: 1
# the Kingdom of Judah: 1
# the Bnei Menashe: 3
# Kolasib: 1
# Beit Shemesh: 1
# Santa Clara: 1
# Moldova: 1
# Ansarallah: 1
# Mediterranean’s: 1
# Eurasia: 1
# Heliopolis: 1
# al-Fawakhir: 1
# Levant: 1
# Gaza City’s Zeitoun: 1
# the Old City of Gaza: 1
# Mecca: 1
# Gaza’s Daraj: 1
# Al-Masjid al-Omari al-Kabir: 1
# Byzantium: 1
# the Via Maris: 2
# Anthedon: 1
# Balakhiyah: 1
# Tida: 1
# Tell el-Ajjul: 1
# Calves Hill: 1
# Daraj: 1
# Ahmadiyyah Zawiya: 1
# the Eastern Mediterranean: 1
# Gaza‘s: 1
# @TomWhiteGaza: 1
# Netivot: 1
# Bab-el-Mandeb strait: 1
# Eilat: 2
# Dead Sea: 1
# Eastern Mediterranean region: 1
# al-Karama: 1
# Paltel: 1
# Jawwal: 1
# Syria’s Golan Heights: 1
# Kurdistan: 1
# Panjgur, Pakistan’s Balochistan province: 1
# Bahaa el-Din Abu Ras: 1
# Dura: 2
# Bahaa’s: 1
# Maldives: 1
# @RepJayapal: 1
# @RepCori: 1
# @BasedMikeLee: 1
# the Republic of Korea: 1
# Kosovo: 1
# PA: 1
# Oslo: 2

# %% [markdown]
# #Clean up the named entity names: check if the data contains duplicates and merge
# the duplicates, using conditions: e.g., add the count for “Gaza’s” to “Gaza” and
# remove “Gaza’s” from the dictionary.

# %%
# Initialize Stanza pipeline
# stanza.download('en')
# nlp = stanza.Pipeline('en', processors='tokenize,ner')

def normalize_place_name(place):
    """Normalize place names using standardized naming conventions"""
    place = place.strip()

    # Remove common prefixes and suffixes
    place = re.sub(r'^the\s+', '', place, flags=re.IGNORECASE)
    place = re.sub(r'[\'’]s', '', place)

    # Standard naming conventions dictionary
    standard_names = {
        # Region normalizations
        'gaza': 'Gaza',  # Catches all Gaza variants

        # Country abbreviations
        'US': 'United States',
        'U.S.': 'United States',
        'USA': 'United States',
        'UK': 'United Kingdom',
        'UAE': 'United Arab Emirates',
        'Britain': 'United Kingdom',

        # Official names to common names
        'State of Israel': 'Israel',
        'Islamic Republic of Iran': 'Iran',
        'Republic of Yemen': 'Yemen',
        'State of Palestine': 'Palestine',

        # Common misspellings
        'Beruit': 'Beirut',
        'Dahiyeb': 'Dahiyeh',
        'Tel Israel': 'Tel Aviv',

        # Sub-region normalizations
        'WestBank': 'West Bank',
        'Gaza Strip': 'Gaza',
        'Gaza City': 'Gaza'
    }

    # Check for Gaza first (special case)
    if re.search(r'gaza', place.lower()):
        return standard_names['gaza']

    # Return standardized name if exists, otherwise original
    return standard_names.get(place, place)

# Initialize places dictionary
places = {}

folder = "/content/FASDH25-portfolio2/articles"

for filename in os.listdir(folder):
    if filename.startswith("2024-01-"):
        path = os.path.join(folder, filename)
        with open(path, encoding="utf-8") as file:
            text = file.read()
        doc = nlp(text)

        for sentence in doc.sentences:
            for ent in sentence.ents:
                if ent.type in ["GPE", "LOC"]:
                    normalized = normalize_place_name(ent.text)
                    if normalized in places:
                        places[normalized] += 1
                    else:
                        places[normalized] = 1

print(places)
# Out:
# {'Morocco': 14, 'Israel': 1632, 'Gaza': 1830, 'Rabat': 3, 'United States': 877, 'United Arab Emirates': 21, 'Bahrain': 11, 'Sudan': 3, 'Western Sahara': 4, 'Washington': 62, 'Tel Aviv': 52, 'Algeria': 7, 'Marrakesh': 1, 'Maghreb': 1, 'Ukraine': 47, 'Saudi Arabia': 39, 'California': 3, 'West Bank': 164, 'Dena': 1, 'Oakland': 1, 'South Africa': 208, 'Jordan': 43, 'Jerusalem': 26, 'East Jerusalem': 23, 'Egypt': 44, 'Qatar': 65, 'Kuala Lumpur': 4, 'Malaysia': 8, 'Palestine': 125, 'Indonesia': 3, 'Jakarta': 2, 'Johannesburg': 4, 'London': 17, 'Paris': 8, 'Vienna': 1, 'Berlin': 5, 'Amman': 6, 'Washington DC': 3, 'United Kingdom': 152, 'Manchester': 1, 'Yemen': 189, 'Washington, DC': 4, 'India': 50, 'Hyderabad': 1, 'Colombo Kollupitiya': 1, 'Namibia': 10, 'Germany': 31, 'Palestinian Territories': 1, 'Sweden': 3, 'Iran': 210, 'Kerman': 6, 'Lebanon': 178, 'Bethlehem': 4, 'Nairoukh': 1, 'China': 30, 'Italy': 10, 'Spain': 7, 'Turkey': 25, 'Shawawra': 1, 'Hague': 39, 'Khan Younis': 23, 'Syria': 84, 'Mazzeh': 2, 'Damascus': 17, 'Houthis’': 3, 'Red Sea': 249, 'Bab-el-Mandeb Strait': 1, 'Gulf of Aden': 27, 'Sanaa': 15, 'Hodeidah': 5, 'Taiz': 2, 'Dhamar': 1, 'al-Bayda': 1, 'Saada': 3, 'Arabian Sea': 6, 'Bab al-Mandeb Strait': 9, 'Asia': 18, 'Europe': 30, 'Kuwait': 2, 'Middle East': 102, 'Ankara': 7, 'West': 24, 'Tehran': 25, 'South Carolina': 4, 'New York City': 1, 'Rafah': 40, 'Strip': 15, 'Istanbul': 2, 'Greece': 8, 'Crete': 2, 'Iraq': 64, 'Gulf': 10, 'al-Dabshah': 1, 'Khirbet Selm': 1, 'Bint Jbeil': 1, 'Beirut': 88, 'Ibil El Saqi': 1, 'al-Tawil': 1, 'al-Khader': 1, 'Bekaa Valley': 1, 'Litani River': 1, 'Netherlands': 14, 'Malta': 2, 'Gulf of Oman': 2, 'Davos': 7, 'Switzerland': 9, 'Deir el-Balah': 14, 'Maghazi': 5, 'Nuseirat': 11, 'Manchester City': 1, 'Barcelona': 1, 'Bab el-Mandeb strait': 1, 'Djibouti': 4, 'Southern Red Sea': 1, 'Africa Cape of Good Hope': 1, 'al-Shifa': 2, 'Gretna': 2, 'Louisiana': 3, 'New Orleans': 5, '@MirandaCleland': 1, 'France': 14, '@majedalansari': 1, 'Kan': 1, 'al-Mawasi district': 2, 'Mediterranean': 12, 'Africa': 29, 'Jenin': 19, 'Thameen Darby': 1, 'Nakba Layer': 1, 'Russia': 43, 'Canada': 42, 'Mercator': 1, 'Alaska': 1, 'Mexico': 5, 'South America': 2, 'Asia-Pacific': 1, 'Golan Heights': 3, 'Crimea': 4, 'South China Sea': 2, 'Philippines': 4, 'Vietnam': 1, 'Pakistan': 24, 'Kashmir': 4, 'New Delhi': 6, 'Islamabad': 3, 'Darby Nakba': 1, 'Hebron': 10, 'Lama Khater': 1, 'Kiryat Arba': 2, 'Bureij': 2, 'al-Mahatta': 1, 'Belgium': 16, 'al-Mazra’a': 1, 'Mediterranean Sea': 2, 'Ajaq': 1, 'Silwad': 1, 'Cairo': 6, 'Australia': 13, 'Denmark': 3, 'New Zealand': 2, 'South Korea': 1, 'Norway': 11, 'Hamas': 6, 'Yaroun': 3, 'Lebanon Nabatieh': 1, 'Yir’on': 1, 'Avivim': 1, 'Israel Goren': 1, 'Shatila': 3, 'Dahiyeh': 7, 'DC': 14, 'Doha': 19, 'Lisbon': 1, 'Portugal': 3, 'Walla': 2, 'Somalia': 1, 'Yemen Red Sea': 1, 'Yemen coast': 2, 'Seychelles': 1, 'Bab al-Mandeb strait': 3, 'North Africa': 5, 'Marib': 3, 'Khreis': 1, 'Hong Kong': 2, 'Bolivia': 4, 'Bangladesh': 2, 'Comoros': 2, 'Myanmar': 6, 'Erbil': 13, 'Pakistan Balochistan province': 2, 'Iran Sistan-Baluchestan province': 2, 'Afghanistan': 7, 'Rask': 1, 'Sistan-Baluchestan': 1, 'Strait of Hormuz': 3, 'Persian Gulf': 1, 'Balochistan': 1, 'Red Sea.': 1, 'La France': 1, 'Entebbe': 1, 'Uganda': 12, 'Montreal': 1, 'Milton, Ontario': 1, 'Jabalia': 11, 'Ottawa': 3, 'Toronto': 1, 'Calgary': 1, 'New York': 4, 'Belarus': 1, 'Munich': 2, 'Haifa': 8, 'Sidon': 3, 'Salameh': 1, 'al-Mughraqa': 1, 'al-Maghazi': 1, 'Maghazi Roads': 1, 'Deir al-Balah': 1, 'Islamic Republic': 5, 'Nur Shams': 1, 'Tulkarem': 2, 'Naqoura': 2, 'America': 4, 'El Arish': 3, 'Al Jazeera': 1, 'al-Mawasi': 3, 'Beirut Shatila': 1, 'Al-Fukhari': 1, 'Zeitoun': 4, 'al-Fukhari': 2, 'Hajjah': 2, 'Ramallah': 24, 'Abwein': 1, 'Nablus': 5, 'Qalqilya': 2, 'Jericho': 1, 'Ein al-Hilweh': 1, 'Basel': 3, 'Ofer': 1, 'Jordan Valley': 5, 'Area C': 6, 'Kadri': 1, 'al-Jiftlik': 1, 'Farsiya': 1, 'Makhoul': 1, 'Tubas': 1, 'Areas A': 1, ' ...

# %% [markdown]
# ### Storing data in a tsv file
#
# We can now store the counts in a tsv file, so we can reuse it in a different script.
#
# Let's create a tsv file with two columns: "name" and "frequency".
# We'll create the tsv file in two steps:
#
# 1. we create the header: that is, the column names, separated by tabs
# 2. we loop through all the place names, and we create a new row in the table for each place. Each row will contain the place name and its frequency, separated by a tab. Each row will have to start on a new line, so we'll also have to add a newline character \n to the row; should we add it at the beginning or end of the line, or both?
#
# Fill in the blanks:

# %% [markdown]
# Storing tsv

# %%
# Define the name and path of the output file
filename = "/content/FASDH25-portfolio2/ner_counts.tsv"

# Open the file in writing mode using UTF-8 encoding
with open(filename, mode="w", encoding="utf-8") as file:
    # Create the header line: column names separated by a tab
    header = "Place\tCount\n"
    file.write(header)

    # Loop through the places dictionary (cleaned place names and their counts)
    for place, count in places.items():
        # Create a row with the place and count separated by a tab
        row = f"{place}\t{count}\n"
        file.write(row)

# %% [markdown]
# The file will now be stored in our colab's session environment. You can see it by clicking the folder icon in the left-hand tool bar in colab. Double-click it to view it in colab. Right-click it and choose "Download" to download the file.
#
# To access it in your script, use the path `/content/ner_counts.tsv`

# %%
# Open the file from the path where it's stored
with open("/content/FASDH25-portfolio2/ner_counts.tsv", encoding="utf-8") as file:
    print(file.read())
# Out:
# Place	Count
# Morocco	14
# Israel	1632
# Gaza	1830
# Rabat	3
# United States	877
# United Arab Emirates	21
# Bahrain	11
# Sudan	3
# Western Sahara	4
# Washington	62
# Tel Aviv	52
# Algeria	7
# Marrakesh	1
# Maghreb	1
# Ukraine	47
# Saudi Arabia	39
# California	3
# West Bank	164
# Dena	1
# Oakland	1
# South Africa	208
# Jordan	43
# Jerusalem	26
# East Jerusalem	23
# Egypt	44
# Qatar	65
# Kuala Lumpur	4
# Malaysia	8
# Palestine	125
# Indonesia	3
# Jakarta	2
# Johannesburg	4
# London	17
# Paris	8
# Vienna	1
# Berlin	5
# Amman	6
# Washington DC	3
# United Kingdom	152
# Manchester	1
# Yemen	189
# Washington, DC	4
# India	50
# Hyderabad	1
# Colombo Kollupitiya	1
# Namibia	10
# Germany	31
# Palestinian Territories	1
# Sweden	3
# Iran	210
# Kerman	6
# Lebanon	178
# Bethlehem	4
# Nairoukh	1
# China	30
# Italy	10
# Spain	7
# Turkey	25
# Shawawra	1
# Hague	39
# Khan Younis	23
# Syria	84
# Mazzeh	2
# Damascus	17
# Houthis’	3
# Red Sea	249
# Bab-el-Mandeb Strait	1
# Gulf of Aden	27
# Sanaa	15
# Hodeidah	5
# Taiz	2
# Dhamar	1
# al-Bayda	1
# Saada	3
# Arabian Sea	6
# Bab al-Mandeb Strait	9
# Asia	18
# Europe	30
# Kuwait	2
# Middle East	102
# Ankara	7
# West	24
# Tehran	25
# South Carolina	4
# New York City	1
# Rafah	40
# Strip	15
# Istanbul	2
# Greece	8
# Crete	2
# Iraq	64
# Gulf	10
# al-Dabshah	1
# Khirbet Selm	1
# Bint Jbeil	1
# Beirut	88
# Ibil El Saqi	1
# al-Tawil	1
# al-Khader	1
# Bekaa Valley	1
# Litani River	1
# Netherlands	14
# Malta	2
# Gulf of Oman	2
# Davos	7
# Switzerland	9
# Deir el-Balah	14
# Maghazi	5
# Nuseirat	11
# Manchester City	1
# Barcelona	1
# Bab el-Mandeb strait	1
# Djibouti	4
# Southern Red Sea	1
# Africa Cape of Good Hope	1
# al-Shifa	2
# Gretna	2
# Louisiana	3
# New Orleans	5
# @MirandaCleland	1
# France	14
# @majedalansari	1
# Kan	1
# al-Mawasi district	2
# Mediterranean	12
# Africa	29
# Jenin	19
# Thameen Darby	1
# Nakba Layer	1
# Russia	43
# Canada	42
# Mercator	1
# Alaska	1
# Mexico	5
# South America	2
# Asia-Pacific	1
# Golan Heights	3
# Crimea	4
# South China Sea	2
# Philippines	4
# Vietnam	1
# Pakistan	24
# Kashmir	4
# New Delhi	6
# Islamabad	3
# Darby Nakba	1
# Hebron	10
# Lama Khater	1
# Kiryat Arba	2
# Bureij	2
# al-Mahatta	1
# Belgium	16
# al-Mazra’a	1
# Mediterranean Sea	2
# Ajaq	1
# Silwad	1
# Cairo	6
# Australia	13
# Denmark	3
# New Zealand	2
# South Korea	1
# Norway	11
# Hamas	6
# Yaroun	3
# Lebanon Nabatieh	1
# Yir’on	1
# Avivim	1
# Israel Goren	1
# Shatila	3
# Dahiyeh	7
# DC	14
# Doha	19
# Lisbon	1
# Portugal	3
# Walla	2
# Somalia	1
# Yemen Red Sea	1
# Yemen coast	2
# Seychelles	1
# Bab al-Mandeb strait	3
# North Africa	5
# Marib	3
# Khreis	1
# Hong Kong	2
# Bolivia	4
# Bangladesh	2
# Comoros	2
# Myanmar	6
# Erbil	13
# Pakistan Balochistan province	2
# Iran Sistan-Baluchestan province	2
# Afghanistan	7
# Rask	1
# Sistan-Baluchestan	1
# Strait of Hormuz	3
# Persian Gulf	1
# Balochistan	1
# Red Sea.	1
# La France	1
# Entebbe	1
# Uganda	12
# Montreal	1
# Milton, Ontario	1
# Jabalia	11
# Ottawa	3
# Toronto	1
# Calgary	1
# New York	4
# Belarus	1
# Munich	2
# Haifa	8
# Sidon	3
# Salameh	1
# al-Mughraqa	1
# al-Maghazi	1
# Maghazi Roads	1
# Deir al-Balah	1
# Islamic Republic	5
# Nur Shams	1
# Tulkarem	2
# Naqoura	2
# America	4
# El Arish	3
# Al Jazeera	1
# al-Mawasi	3
# Beirut Shatila	1
# Al-Fukhari	1
# Zeitoun	4
# al-Fukhari	2
# Hajjah	2
# Ramallah	24
# Abwein	1
# Nablus	5
# Qalqilya	2
# Jericho	1
# Ein al-Hilweh	1
# Basel	3
# Ofer	1
# Jordan Valley	5
# Area C	6
# Kadri	1
# al-Jiftlik	1
# Farsiya	1
# Makhoul	1
# Tubas	1
# Areas A	1
# Japan	9
# Silicon Valley	3
# Netanyahu	7
# West Jerusalem	1
# Brussels	5
# League of Arab States	1
# West Beirut	9
# Beirut Hamra	1
# Hamra	3
# West Beirutis	1
# Dabbouch	1
# East Beirut	1
# Austria	3
# Finland	3
# Iceland	1
# Romania	4
# Melbourne, Australia	1
# Melbourne	5
# Sandridge Beach	1
# ZIM Ganges	5
# Sydney	1
# Brisbane	1
# Rawaa	1
# Middle East Eye	1
# Near East	3
# Kyiv	5
# Houthi	3
# Aqaba	1
# Marshall Islands	1
# Aden	3
# Sabra	1
# Farhana	1
# Abudaqa	2
# Israel-Palestine	2
# Shujayea	3
# Khan Yunis	1
# Mawasi	1
# Bosnia	3
# Sri Lanka	2
# Republic of South Africa	1
# Columbia	3
# Chile	5
# Santiago	1
# Taiz province	1
# Al-Bayda	1
# Ashdod	2
# Hebrew	1
# X.
# Spain	1
# Madrid	1
# Oman	1
# Charleston	1
# Geneva	2
# Al-Aqsa	1
# Zawayda	1
# Beit Hanoon	1
# Serbia	3
# Bosnia-Herzegovina	1
# Srebrenica	1
# Bani Suheila	2
# Caesarea	2
# Kefar Sava	1
# Rehovot	1
# Beersheba	1
# Kiryat Shmona	1
# Blue Line	1
# Baghdad	8
# Middle Eastern	3
# Welch	1
# Global South	2
# @NaksBilal	1
# Beit Lahiya	2
# El Amal City Hospital	1
# Maroun El Ras	1
# Rmeish	1
# Miraj	1
# Tal al-Hawa	1
# @zarahsultana	1
# Gisha	1
# Bani Naim	1
# Raanana	1
# Sderot	2
# Nir Am	1
# Mefalsim	1
# Hanita	1
# Mattat	1
# Margaliot	1
# Adamit	1
# Zar’it	1
# Malkia	1
# Herzegovina	1
# Montenegro	1
# Yugoslavia	2
# Moscow	4
# Pretoria	8
# Mozambique	1
# United States’	2
# Bulgaria	1
# Shadi	1
# Ebel el-Saqi	1
# Panjgur	1
# Sistan-Baluchestan province	1
# Ocean Jazz	1
# Cape of Good Hope	12
# al-Walaja	5
# Gilo	1
# Har Gilo	1
# Singapore	2
# Ras Issa	1
# Hodeidah province	1
# Dearborn	12
# Michigan	12
# Mackinac Island	1
# Great Lakes	1
# Lake Michigan	1
# Texas	3
# Beit Nabala	1
# Idlib	3
# Riyadh	5
# Alborz	4
# Southern Africa	2
# Bab al-Mandeb	2
# Venezuela	1
# Hormuz	1
# Arabian Gulf	1
# Dublin	3
# Al Rayyan	1
# Cape Town	2
# South Africansfrom	1
# Africa4Palestine	1
# Western Cape province	1
# Chicago	2
# Cyprus	9
# Akrotiri	12
# Limassol	1
# Pashias	1
# Anadolu	1
# Nevatim	1
# Republic of Cyprus	2
# Dhekelia	1
# al-Saftawi	1
# Detroit	1
# Southeast Michigan	1
# Arab America	1
# Jarrah	1
# Wayne County	1
# Minnesota	1
# Scotland	2
# Ireland	3
# #October7	2
# Entebbe, Uganda	1
# Sierra Leone	1
# DRC	1
# @adoniaayebare	1
# Aroura	2
# al-Arouri	2
# Salem	1
# Copenhagen	1
# Tunisia	2
# Syria Aleppo	1
# Mariupol	1
# Indian Ocean	2
# Kanaker	1
# Sarit	1
# Aleppo	2
# al-Tanf	1
# Hashemite Kingdom of Jordan	1
# Jordan River	1
# @Palestine_UN	1
# India Basmati	1
# North America	2
# Earth	1
# al-Amal	4
# al-Nasser	1
# al-Katiba	1
# Rohtak	6
# Haryana	3
# Uttar Pradesh	1
# Lucknow	1
# UP	1
# Bihar	4
# West Bengal	1
# @Benarasiyaa	1
# Haryana Panipat	1
# Thailand	2
# Haryana Jind	1
# Al Maniya	1
# Bab al-	1
# Mandeb Strait	1
# al-Mazraa Asharqiya	1
# Harvey	1
# Tawfiq	1
# al-Mazra’a Asharqiya	1
# Hamoud	1
# Taalbaya	1
# Rashidiya	1
# Karem Abu Salem	1
# Kerem Shalom	1
# Estonia	1
# Kampala	5
# Peru	1
# Colombia	1
# South Sudan	1
# Swaziland	1
# #RedSea	1
# Bern	1
# Zurich	1
# Arura	2
# Hezbollah	1
# Deir Qaddis	1
# MoTaz	1
# @azaizamotaz9	1
# Israel Haifa	1
# Dubai	1
# Yemen southern coast	1
# Egypt Sinai Peninsula	1
# Philadelphi	1
# Dahiya	1
# Jama’a Islamiya	2
# Cameroon	1
# al-Ahli	1
# Des Moines	7
# Iowa	12
# Cedar Rapids	5
# Iowa City	5
# South Asia	1
# Florida	1
# New York Ellis Island	1
# Ohio	1
# Czech Republic	1
# Hungary	1
# Slovenia	1
# @carogennez	1
# Flanders	1
# Wallonia	1
# Supernova	1
# Syria Damascus	1
# Borj el Barajneh	1
# Libya	3
# Rwanda	1
# East Timor	1
# Kabul	1
# az-Zahra	1
# Hamad	1
# State of Qatar	1
# QFFD	1
# Aizawl	6
# Manipur	8
# Kangpokpi	1
# Mizoram	8
# Kingdom of Judah	1
# Bnei Menashe	3
# Kolasib	1
# Beit Shemesh	1
# Santa Clara	1
# Moldova	1
# Ansarallah	1
# Eurasia	1
# Heliopolis	1
# al-Fawakhir	1
# Levant	1
# Mecca	1
# Al-Masjid al-Omari al-Kabir	1
# Byzantium	1
# Via Maris	2
# Anthedon	1
# Balakhiyah	1
# Tida	1
# Tell el-Ajjul	1
# Calves Hill	1
# Daraj	1
# Ahmadiyyah Zawiya	1
# Eastern Mediterranean	1
# Netivot	1
# Bab-el-Mandeb strait	1
# Eilat	2
# Dead Sea	1
# Eastern Mediterranean region	1
# al-Karama	1
# Paltel	1
# Jawwal	1
# Syria Golan Heights	1
# Kurdistan	1
# Panjgur, Pakistan Balochistan province	1
# Bahaa el-Din Abu Ras	1
# Dura	2
# Bahaa	1
# Maldives	1
# @RepJayapal	1
# @RepCori	1
# @BasedMikeLee	1
# Republic of Korea	1
# Kosovo	1
# PA	1
# Oslo	2

# %% [markdown]
# Now, reuse the code above to get the coordinates for the place names from the places we stored in the `ner_counts.tsv` file.
#
# Write a new tsv file, `ner_gazetteer.tsv`, which contains three columns: name, latitude, longitude.
